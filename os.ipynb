# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n-cls.pt")
model.train(
    data="dataset",
    epochs=70,
    imgsz=224,
    batch=16
)
# Out:
# ...
# 100%|██████████| 5.52M/5.52M [00:00<00:00, 97.1MB/s]
# New https://pypi.org/project/ultralytics/8.4.33 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40  Python-3.9.25 torch-2.8.0+cpu CPU (13th Gen Intel Core(TM) i5-13420H)
# ...

# %%
model = YOLO("runs/classify/train/weights/best.pt")

image_paths = [
    "dataset/test/normal/Normal 704.jpg",
    "dataset/test/osteoporosis/Osteoporosis 730.jpg",
    "dataset/test/normal/Normal 710.jpg"
]

classes = ["normal", "osteoporosis"]

for img_path in image_paths:
    results = model.predict(img_path)

    r = results[0]
    probs = r.probs.data.tolist()

    pred_index = probs.index(max(probs))
    pred_class = classes[pred_index]
    confidence = max(probs)

    print("==== RESULT ====")
    print(f"Image: {img_path}")
    print(f"Prediction: {pred_class.upper()}")
    print(f"Confidence: {confidence*100:.2f}%")
# Out:
# image 1/1 c:\Files for any work\python university\year2-2\CV\newproject\dataset\test\normal\Normal 704.jpg: 224x224 normal 0.60, osteoporosis 0.40, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# ==== RESULT ====
# Image: dataset/test/normal/Normal 704.jpg
# Prediction: NORMAL
# Confidence: 59.64%
#
# image 1/1 c:\Files for any work\python university\year2-2\CV\newproject\dataset\test\osteoporosis\Osteoporosis 730.jpg: 224x224 osteoporosis 1.00, normal 0.00, 14.0ms
# Speed: 4.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# ==== RESULT ====
# Image: dataset/test/osteoporosis/Osteoporosis 730.jpg
# Prediction: OSTEOPOROSIS
# Confidence: 99.99%
#
# image 1/1 c:\Files for any work\python university\year2-2\CV\newproject\dataset\test\normal\Normal 710.jpg: 224x224 normal 0.98, osteoporosis 0.02, 15.0ms
# ...
